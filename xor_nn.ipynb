# %% [markdown]
# <a href="https://colab.research.google.com/github/pltmelek/Yapay-Zeka-/blob/main/xor_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import sys

# %%
training_data=np.array([[0,0],[0,1],[1,0],[1,1]],"float32")
target_data=np.array([[0],[1],[1],[0]],"float32")

# %%
model=tf.keras.models.Sequential()
#layerlari ekle
model.add(tf.keras.layers.Dense(4,input_dim=2,activation='relu'))
model.add(tf.keras.layers.Dense(1,activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',optimizer='adam',metrics='binary_accuracy')
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 4)                 12
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 5
# ...
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(training_data,target_data,epochs=500,verbose=2)
# Out:
# Epoch 1/500
# 1/1 - 0s - loss: 0.0056 - binary_accuracy: 1.0000
# Epoch 2/500
# 1/1 - 0s - loss: 0.0056 - binary_accuracy: 1.0000
# Epoch 3/500
# 1/1 - 0s - loss: 0.0056 - binary_accuracy: 1.0000
# Epoch 4/500
# 1/1 - 0s - loss: 0.0056 - binary_accuracy: 1.0000
# Epoch 5/500
# 1/1 - 0s - loss: 0.0056 - binary_accuracy: 1.0000
# Epoch 6/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 7/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 8/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 9/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 10/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 11/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 12/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 13/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 14/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# Epoch 15/500
# 1/1 - 0s - loss: 0.0055 - binary_accuracy: 1.0000
# ...

# %%
print(model.predict(training_data).round())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
loss_curve=history.history["loss"]
acc_curve=history.history["binary_accuracy"]
plt.plot(loss_curve,label="Train")
plt.legend(loc='upper left')
plt.title("Loss")
plt.show()

# %%
plt.plot(acc_curve,label="Train")
plt.legend(loc='upper left')
plt.title("Accuracy")
plt.show()
